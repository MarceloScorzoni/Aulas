# %% [markdown]
# <a href="https://colab.research.google.com/github/MarceloScorzoni/Aulas/blob/main/untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dic = {'nome':'Fulano', 'sobrenome':'de Tal'}
local = {'UF':'SP', 'cidade':'Sao Carlos'}

dic2 = dic.copy()
dic.update(local)
print(len(dic))
print(f'Dicionario: {dic}')
print(f'Dicionario2: {dic2}')
# Out:
# 4
# Dicionario: {'nome': 'Fulano', 'sobrenome': 'de Tal', 'UF': 'SP', 'cidade': 'Sao Carlos'}
# Dicionario2: {'nome': 'Fulano', 'sobrenome': 'de Tal'}

# %%
aluno = {}
aluno['nome'] = input('Digite o nome do aluno: ')
aluno['media'] = float(input(f'Digite a media do aluno: {aluno["nome"]}: '))
if aluno['media'] >= 7:
  aluno['situação'] = 'Aprovado'
elif 5 <= aluno['media'] < 7:
  aluno['situação'] = 'Recuperação'
else:
  aluno['situação'] = 'Reprovado'
print('=='*30)
for k, v in aluno.items():
  print(f' - {k} é igual a {v}')
# Out:
# Digite o nome do aluno: Marcelo
# Digite a media do aluno: Marcelo: 7
# ...
#  - nome é igual a Marcelo
#  - media é igual a 7.0
#  - situação é igual a Aprovado
